# %%
# Проверка GPU и CUDA
import torch

if torch.cuda.is_available():
    print("GPU доступен!")
    print("Имя GPU:", torch.cuda.get_device_name(0))
    print("Всего памяти GPU (MB):", torch.cuda.get_device_properties(0).total_memory // (1024**2))
    print("CUDA версии:", torch.version.cuda)
else:
    print("GPU недоступен!")
# Out:
# GPU доступен!
# Имя GPU: Tesla T4
# Всего памяти GPU (MB): 15095
# CUDA версии: 12.6

# %%
# !nvcc -o GPU_merge_sort GPU_merge_sort.cu

#nvcc — это компилятор CUDA от NVIDIA

#gpu_merge_sort.cu — исходный файл на CUDA (C/C++ + код для GPU)

# %%
# !./GPU_merge_sort
#-o gpu_merge_sort — имя выходного исполняемого файла
# Out:
# Array size: 10000
# GPU Merge Sort time: 189 ms
#
# Array size: 100000
# GPU Merge Sort time: 0 ms
#
# Array size: 1000000
# GPU Merge Sort time: 2 ms

# %%
# !nvcc -o GPU_quick_sort GPU_quick_sort.cu

# %%
# !./GPU_quick_sort
# Out:
# Array size: 10000
# GPU Quick Sort time: 184 ms
#
# Array size: 100000
# GPU Quick Sort time: 30 ms
#
# Array size: 1000000
# GPU Quick Sort time: 338 ms

# %%
# !nvcc -o GPU_heap_sort GPU_heap_sort.cu

# %%
# !./GPU_heap_sort
# Out:
# Array size: 10000
# GPU Heap Sort time: 474 ms
#
# Array size: 100000
# GPU Heap Sort time: 2784 ms
#
# Array size: 1000000
# GPU Heap Sort time: 28468 ms
